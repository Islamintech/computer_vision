# %% [markdown]
# <a href="https://colab.research.google.com/github/Islamintech/computer_vision/blob/main/cv_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/cat-image.jpeg")
# cv2.imshow("CAT", image)
cv2_imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_649/3235371569.py in <cell line: 0>()
#       3 image = cv2.imread("/content/cat-image.jpeg")
#       4 # cv2.imshow("CAT", image)
# ----> 5 cv2_imshow(image)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print("Shape:", image.shape)
# 0) height =>  1200
# 1) width  =>  1200
# 2) RGB    =>  3 color channels
               # (BGR) => Blue, Green, Red

print("\nHeight:", image.shape[0])
print("Width:", image.shape[1])
print("Channels:", image.shape[2])

# %%
(b, g, r) = image[100, 50]
print(f"Blue: {b}, Green: {g}, Red: {r}")

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)

# %%
resize = cv2.resize(gray, (300, 300))
cv2_imshow(resize)

# %%
cropped = gray[200:400, 200:420]
cv2_imshow(cropped)

# %%
rotated = cv2.rotate(gray, cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(rotated)

# %%
flipped = cv2.flip(cropped, 1)
cv2_imshow(flipped)

# %%
cv2.imwrite("flipped_cat_eye2.jpg", cropped)

# %% [markdown]
# # **OPENCV** VIDEO STREMING CODES

# %%
import cv2
print("Hello MIT")


cap = cv2.VideoCapture(0)

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

while True:
    success, frame = cap.read()

    if not success:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    cv2.imshow("Real-time Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()


# ======================================================================================================================================================================================================


# import cv2
# # url = "rtsp://demo:demo@ipvmdemo.dyndns.org:5541/onvif-media/media.amp?profile=profile_1_h264&sessiontimeout=60&streamtype=unicast" # stream_path
# # cap = cv2.VideoCapture(url)


# cap = cv2.VideoCapture(0)


# while True:
#     success, frame = cap.read()

#     if not success:
#         break

#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     blurred = cv2.GaussianBlur(frame, (35, 35), 0)
#     edges1 = cv2.Canny(frame, 10, 300)
#     edges2 = cv2.Canny(frame, 50, 250)

#     flipped = cv2.flip(frame, 1)

#     cv2.imshow("Original:", frame)
#     # cv2.imshow("Gray:", gray)
#     # cv2.imshow("Blur:", blurred)

#     # cv2.imshow("Edge1:", edges1)
#     # cv2.imshow("Edge2:", edges2)
#     cv2.imshow("Flipped:", flipped)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()
